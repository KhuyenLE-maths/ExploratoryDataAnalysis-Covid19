# %% [markdown]
# <a href="https://colab.research.google.com/github/KhuyenLE-maths/ExploratoryDataAnalysis-Covid19/blob/main/Exploratory_Data_Analysis_(part_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/mount/')
# Out:
# Drive already mounted at /content/mount/; to attempt to forcibly remount, call drive.mount("/content/mount/", force_remount=True).

# %%
import os

# %%
os.chdir('/content/mount/MyDrive/Machine learning')

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('dataset.xlsx')
df.head()
# Out:
#         Patient ID  ...  ctO2 (arterial blood gas analysis)
# 0  44477f75e8169d2  ...                                 NaN
# 1  126e9dd13932f68  ...                                 NaN
# 2  a46b4402a0e5696  ...                                 NaN
# 3  f7d619a94f97c45  ...                                 NaN
# 4  d9e41465789c2b5  ...                                 NaN
#
# [5 rows x 111 columns]

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] <0.9]]

# %%
df = df.drop('Patient ID', axis = 1)

# %%
df.head()
# Out:
#    Patient age quantile  ... Influenza A, rapid test
# 0                    13  ...                     NaN
# 1                    17  ...                negative
# 2                     8  ...                     NaN
# 3                     5  ...                     NaN
# 4                    15  ...                     NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Relation Variables/Variables

# %%
missing_rate = df.isna().sum()/df.shape[0]

# %%
blood_columns = df.columns[(missing_rate < 0.9)&(missing_rate > 0.88)]
viral_columns = df.columns[(missing_rate <0.88)&(missing_rate > 0.75)]

# %%
sns.pairplot(df[blood_columns])

# %%
sns.heatmap(df[blood_columns].corr())

# %%
sns.clustermap(df[blood_columns].corr())

# %% [markdown]
# ### Relation Age/Blood

# %%
for col in blood_columns:
  plt.figure()
  sns.lmplot(x = 'Patient age quantile', y = col, hue = 'SARS-Cov-2 exam result', data = df)
  plt.show()

# %%
df.corr()['Patient age quantile'].sort_values()
# Out:
# Leukocytes                                              -0.166386
# Platelets                                               -0.158683
# Lymphocytes                                             -0.125935
# Mean corpuscular hemoglobin concentration (MCHC)        -0.124671
# Red blood Cells                                         -0.037510
# Patient addmited to intensive care unit (1=yes, 0=no)   -0.035772
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.015736
# Eosinophils                                              0.022085
# Patient addmited to regular ward (1=yes, 0=no)           0.046166
# Monocytes                                                0.050962
# Hemoglobin                                               0.060320
# Hematocrit                                               0.096808
# Basophils                                                0.107525
# Mean platelet volume                                     0.119449
# ...

# %% [markdown]
# **Comment:** The correlation between ages and the above variables are very small.

# %% [markdown]
# ### Relation between **Influanza A** and **Influanza A, rapid test**

# %%
pd.crosstab(df['Influenza A'], df['Influenza A, rapid test'])
# Out:
# Influenza A, rapid test  negative  positive
# Influenza A
# detected                        2         4
# not_detected                  245        15

# %% [markdown]
# ### Relation Viral/Sanguin

# %%
df[viral_columns[:-2]] == 'detected'
# Out:
#       Respiratory Syncytial Virus  ...  Parainfluenza 2
# 0                           False  ...            False
# 1                           False  ...            False
# 2                           False  ...            False
# 3                           False  ...            False
# 4                           False  ...            False
# ...                           ...  ...              ...
# 5639                        False  ...            False
# 5640                        False  ...            False
# 5641                        False  ...            False
# 5642                        False  ...            False
# 5643                        False  ...            False
#
# [5644 rows x 17 columns]

# %%
np.sum(df[viral_columns[:-2]]== 'detected', axis = 1).plot()

# %%
df['detected'] = np.sum(df[viral_columns[:-2]] == 'detected', axis = 1) >= 1

# %%
df.head()
# Out:
#    Patient age quantile  ... detected
# 0                    13  ...    False
# 1                    17  ...     True
# 2                     8  ...    False
# 3                     5  ...    False
# 4                    15  ...     True
#
# [5 rows x 39 columns]

# %%
detected_df = df[df['detected'] == True]
not_detected_df = df[df['detected'] == False]

# %%
detected_df.shape
detected_df.head()
# Out:
#     Patient age quantile  ... detected
# 1                     17  ...     True
# 4                     15  ...     True
# 15                     9  ...     True
# 18                    11  ...     True
# 20                     0  ...     True
#
# [5 rows x 39 columns]

# %%
not_detected_df.shape
# Out:
# (4952, 39)

# %%
for col in blood_columns:
  plt.figure()
  sns.distplot(detected_df[col], label = 'detected')
  sns.distplot(not_detected_df[col], label = 'not_detected')
  plt.legend()
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Relation Hospitalizaiton/detected

# %%
def hospital(df):
  if df['Patient addmited to regular ward (1=yes, 0=no)'] == 1:
    return 'surveillance'
  elif df['Patient addmited to semi-intensive unit (1=yes, 0=no)'] == 1:
    return 'semi intensive care'
  elif df['Patient addmited to intensive care unit (1=yes, 0=no)'] == 1:
    return 'intensive care'
  else: 
    return 'unknown'

# %%
df['status'] = df.apply(hospital, axis = 1) # axis = 1: apply into columns

# %%
df.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  ...  detected   status
# 0                    13               negative  ...     False  unknown
# 1                    17               negative  ...      True  unknown
# 2                     8               negative  ...     False  unknown
# 3                     5               negative  ...     False  unknown
# 4                    15               negative  ...      True  unknown
#
# [5 rows x 40 columns]

# %%
df.shape
# Out:
# (5644, 40)

# %%
for col in blood_columns:
  plt.figure()
  for cat in df['status'].unique():
    sns.distplot(df[df['status']== cat][col], label = cat)
  plt.legend()
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Hypothesis testing:
# Based on the above results, we see that the Covid 19 patients have different ratios of Leukocytes, Monocytes and Platelets.
# We aim to test the following null hypothesis:
#
# H0: The means of positive and negative patients are equal.
#
# ### T-test

# %%
from scipy.stats import ttest_ind

# %%
positive_df = df[df['SARS-Cov-2 exam result'] == 'positive']
negative_df = df[df['SARS-Cov-2 exam result'] == 'negative']

# %%
positive_df.shape
# Out:
# (558, 40)

# %%
negative_df.shape
# Out:
# (5086, 40)

# %%
balanced_neg = negative_df.sample(positive_df.shape[0])

# %%
def t_test(col):
  alpha = 0.02
  stat, p = ttest_ind(balanced_neg[col].dropna(), positive_df[col].dropna())
  if p < alpha:
    return 'reject H0'
  else:
    return '0'

# %%
for col in blood_columns:
  print(f'{col :-<50}{t_test(col)}')
# Out:
# Hematocrit----------------------------------------0
# Hemoglobin----------------------------------------0
# Platelets-----------------------------------------reject H0
# Mean platelet volume -----------------------------0
# Red blood Cells-----------------------------------0
# Lymphocytes---------------------------------------0
# Mean corpuscular hemoglobin concentration (MCHC)--0
# Leukocytes----------------------------------------reject H0
# Basophils-----------------------------------------0
# Mean corpuscular hemoglobin (MCH)-----------------0
# Eosinophils---------------------------------------reject H0
# Mean corpuscular volume (MCV)---------------------0
# Monocytes-----------------------------------------reject H0
# Red blood cell distribution width (RDW)-----------0
