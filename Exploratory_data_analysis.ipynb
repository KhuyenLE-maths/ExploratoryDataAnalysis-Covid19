# %% [markdown]
# <a href="https://colab.research.google.com/github/KhuyenLE-maths/ExploratoryDataAnalysis-Covid19/blob/main/Exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Machine learning/')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_excel('dataset.xlsx')

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %% [markdown]
# ## Analyse dataset

# %%
data.shape
# Out:
# (5644, 111)

# %%
df = data.copy()

# %% [markdown]
# type of each column

# %%
df.dtypes
# Out:
# Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
# Patient addmited to intensive care unit (1=yes, 0=no)      int64
# Hematocrit                                               float64
# Hemoglobin                                               float64
# Platelets                                                float64
# Mean platelet volume                                     float64
# Red blood Cells                                          float64
# Lymphocytes                                              float64
# Mean corpuscular hemoglobin concentration (MCHC)         float64
# Leukocytes                                               float64
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    70
# object     37
# int64       4
# dtype: int64

# %%
df.dtypes.value_counts().plot.pie()

# %% [markdown]
# Setting display maximum number of rows and columns

# %%
pd.set_option('display.max_row',111)
pd.set_option('display.max_column', 111)

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %% [markdown]
# Verify if there exist NaN values in the data frame

# %%
df.isna()
# Out:
#       Patient ID  Patient age quantile  SARS-Cov-2 exam result  \
# 0          False                 False                   False
# 1          False                 False                   False
# 2          False                 False                   False
# 3          False                 False                   False
# 4          False                 False                   False
# ...          ...                   ...                     ...
# 5639       False                 False                   False
# 5640       False                 False                   False
# 5641       False                 False                   False
# 5642       False                 False                   False
# 5643       False                 False                   False
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                              False
# 1                                              False
# ...

# %%
sns.heatmap(df.isna())

# %% [markdown]
# In the abow image, the white color presents the NaN values in the data frame.

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.isna(), cbar = False)

# %% [markdown]
# Compute total NaN values in each column:

# %%
df.isna().sum()
# Out:
# Patient ID                                                  0
# Patient age quantile                                        0
# SARS-Cov-2 exam result                                      0
# Patient addmited to regular ward (1=yes, 0=no)              0
# Patient addmited to semi-intensive unit (1=yes, 0=no)       0
# Patient addmited to intensive care unit (1=yes, 0=no)       0
# Hematocrit                                               5041
# Hemoglobin                                               5041
# Platelets                                                5042
# Mean platelet volume                                     5045
# Red blood Cells                                          5042
# Lymphocytes                                              5042
# Mean corpuscular hemoglobin concentration (MCHC)         5042
# Leukocytes                                               5042
# Basophils                                                5042
# ...

# %% [markdown]
# Ratio of NaN values in each column:

# %%
pd.set_option('display.max_row',111) # set the maximum number of displayed rows to 111.

# %%
df.isna().sum()/df.shape[0]
# Out:
# Patient ID                                               0.000000
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Hematocrit                                               0.893161
# Hemoglobin                                               0.893161
# Platelets                                                0.893338
# Mean platelet volume                                     0.893870
# Red blood Cells                                          0.893338
# Lymphocytes                                              0.893338
# Mean corpuscular hemoglobin concentration (MCHC)         0.893338
# Leukocytes                                               0.893338
# ...

# %% [markdown]
# Order the obove table in ascending order:

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending = True)
# Out:
# Patient ID                                               0.000000
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Influenza B                                              0.760099
# Respiratory Syncytial Virus                              0.760099
# Influenza A                                              0.760099
# Rhinovirus/Enterovirus                                   0.760454
# Inf A H1N1 2009                                          0.760454
# CoronavirusOC43                                          0.760454
# Coronavirus229E                                          0.760454
# Parainfluenza 4                                          0.760454
# ...

# %% [markdown]
# ## Data analysis:
# ### 1. Eliminate un-useful columns

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] < 0.9]]
print(df.shape)
df.head()
# Out:
# (5644, 39)
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# ...

# %% [markdown]
# Visualize new dataset

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.isna(), cbar = False)

# %% [markdown]
# Drop the column **'Patient ID'** which is not useful:

# %%
df = df.drop('Patient ID', axis = 1)
df.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  \
# 0                    13               negative
# 1                    17               negative
# 2                     8               negative
# 3                     5               negative
# 4                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %% [markdown]
# ### Exam the column target

# %%
df['SARS-Cov-2 exam result'].value_counts(normalize = True)
# Out:
# negative    0.901134
# positive    0.098866
# Name: SARS-Cov-2 exam result, dtype: float64

# %% [markdown]
# ### Histogram of continuous variables:

# %%
for col in df.select_dtypes('float64'): 
  plt.figure()
  sns.distplot(df[col])
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Visualize column **'Patient age quantile'**

# %%
df['Patient age quantile'].value_counts()
# Out:
# 11    380
# 4     366
# 9     359
# 0     334
# 7     319
# 2     315
# 13    313
# 14    299
# 5     294
# 6     281
# 16    279
# 19    275
# 15    269
# 17    263
# 18    259
# 3     251
# 1     234
# 12    197
# 10    190
# 8     167
# Name: Patient age quantile, dtype: int64

# %%
sns.distplot(df['Patient age quantile'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Quanlitative variables

# %% [markdown]
# Display columns with quanlitative variables:

# %%
df.select_dtypes('object').head()
# Out:
#   SARS-Cov-2 exam result Respiratory Syncytial Virus   Influenza A  \
# 0               negative                         NaN           NaN
# 1               negative                not_detected  not_detected
# 2               negative                         NaN           NaN
# 3               negative                         NaN           NaN
# 4               negative                not_detected  not_detected
#
#     Influenza B Parainfluenza 1 CoronavirusNL63 Rhinovirus/Enterovirus  \
# 0           NaN             NaN             NaN                    NaN
# 1  not_detected    not_detected    not_detected               detected
# 2           NaN             NaN             NaN                    NaN
# 3           NaN             NaN             NaN                    NaN
# 4  not_detected    not_detected    not_detected               detected
#
#   Coronavirus HKU1 Parainfluenza 3 Chlamydophila pneumoniae    Adenovirus  \
# ...

# %%
for col in df.select_dtypes('object'):
  print(f'{col :-<50}{df[col].unique()}')
# Out:
# SARS-Cov-2 exam result----------------------------['negative' 'positive']
# Respiratory Syncytial Virus-----------------------[nan 'not_detected' 'detected']
# Influenza A---------------------------------------[nan 'not_detected' 'detected']
# Influenza B---------------------------------------[nan 'not_detected' 'detected']
# Parainfluenza 1-----------------------------------[nan 'not_detected' 'detected']
# CoronavirusNL63-----------------------------------[nan 'not_detected' 'detected']
# Rhinovirus/Enterovirus----------------------------[nan 'detected' 'not_detected']
# Coronavirus HKU1----------------------------------[nan 'not_detected' 'detected']
# Parainfluenza 3-----------------------------------[nan 'not_detected' 'detected']
# Chlamydophila pneumoniae--------------------------[nan 'not_detected' 'detected']
# Adenovirus----------------------------------------[nan 'not_detected' 'detected']
# Parainfluenza 4-----------------------------------[nan 'not_detected' 'detected']
# ...

# %%
for col in df.select_dtypes('object'):
  plt.figure()
  df[col].value_counts().plot.pie()

# %% [markdown]
# ### Relation target/variables

# %% [markdown]
# Create positive and negative subsets:

# %%
positive_df = df[df['SARS-Cov-2 exam result'] == 'positive']
negative_df = df[df['SARS-Cov-2 exam result'] == 'negative']

# %% [markdown]
# Create blood and viral subsets

# %%
missing_rate = df.isna().sum()/df.shape[0]

# %%
missing_rate
# Out:
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
# Hematocrit                                               0.893161
# Hemoglobin                                               0.893161
# Platelets                                                0.893338
# Mean platelet volume                                     0.893870
# Red blood Cells                                          0.893338
# Lymphocytes                                              0.893338
# Mean corpuscular hemoglobin concentration (MCHC)         0.893338
# Leukocytes                                               0.893338
# Basophils                                                0.893338
# ...

# %%
blood_columns = df.columns[(missing_rate < 0.9) & (missing_rate > 0.88)]
viral_columns = df.columns[(missing_rate < 0.88) & (missing_rate > 0.75)]

# %% [markdown]
# ## Targets/Blood

# %%
for col in blood_columns:
  plt.figure()
  sns.distplot(positive_df[col], label = 'positive')
  sns.distplot(negative_df[col], label = 'negative')
  plt.legend()
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Comment:**
# *From* the above figure, we see that the ratio of Platelets, Leukocytes and Monocytes are related to covid 19.

# %% [markdown]
# ### Relation Target/Age

# %%
sns.countplot(x = 'Patient age quantile', hue = 'SARS-Cov-2 exam result', data = df)

# %% [markdown]
# ### Relation Target/viral

# %%
pd.crosstab(df['SARS-Cov-2 exam result'], df['Influenza A'])
# Out:
# Influenza A             detected  not_detected
# SARS-Cov-2 exam result
# negative                      18          1224
# positive                       0           112

# %%
for col in viral_columns:
  plt.figure()
  sns.heatmap(pd.crosstab(df['SARS-Cov-2 exam result'], df[col]), annot = True)
